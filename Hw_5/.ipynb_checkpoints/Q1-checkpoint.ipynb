# %%
# Plotting libraries
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style='dark')

# Data libraries
import numpy as np
import pandas as pd
import math

# %%
def stdform(Rarr):
    tconst = []
    tconst1 = []
    tconst2 = []
    parr = []
    for R in Rarr:
        timeconst = math.sqrt((0.01)/(((R+1.001)**2)-R-(R**2)))
        
        a = (0.01)/(((R+1.001)**2)-R-(R**2))
        b = (0.2*(R+1.001))/(((R+1.001)**2)-R-(R**2))
        c = 1
        
        root1 = ((b**2)+math.sqrt(4*a*c))/(2*a)
        root2 = ((b**2)-math.sqrt(4*a*c))/(2*a)
        poles = [root1,root2]
        
        z = b/(2*timeconst)
        t1 = timeconst/(z-(math.sqrt((z**2)-1)))
        t2 = timeconst/(z+(math.sqrt((z**2)-1)))
        
        tconst.append(timeconst)
        tconst1.append(t1)
        tconst2.append(t2)
        parr.append(poles)
        
    return [tconst,tconst1,tconst2,parr]

# %%
R = np.linspace(0,15,1000)
ret = stdform(R)
tconst = ret[0]
tconst1 = ret[1]
tconst2 = ret[2]
poles = ret[3]
poles1 = [i[0] for i in poles]
poles2 = [i[1] for i in poles]

# %%
print(poles)
# Out:
# [[12.009999999999998, -8.009999999999998], [12.114840139094742, -8.054900018329644], [12.219128524691117, -8.099248281442685], [12.322877178333927, -8.143056810957985], [12.426097691266989, -8.186337198189232], [12.528801245692431, -8.229100625404515], [12.630998634698356, -8.27135788575426], [12.73270028095538, -8.31311940196802], [12.833916254273754, -8.354395243911844], [12.934656288104865, -8.39519514508993], [13.034929795063558, -8.435528518167208], [13.134745881541493, -8.475404469582815], [13.234113361475657, -8.514831813318821], [13.333040769331049, -8.553819083883027], [13.431536372351609, -8.592374548560056], [13.529608182129227, -8.63050621898049], [13.627263965536622, -8.668221862053864], [13.724511255066364, -8.705529010307796], [13.821357358614945, -8.742434971672177], [13.917809368747927, -8.778946838744414], [14.013874171479385, -8.815071497568937], [14.109558454596414, -8.850815635961823], [14.204868715557195, -8.886185751408927], [14.299811268988998, -8.921188158563945], [14.394392253810631, -8.955828996370967], [14.488617640002083, -8.990114234834136], [14.582493235042456, -9.024049681455676], [14.67602469003587, -9.057640987361847], [14.769217505543601, -9.090893653135113], [14.862077037139516, -9.123813034369658], [14.954608500704673, -9.156404346966008], [15.046816977475867, -9.188672672179624], [15.138707418862028, -9.220622961437357], [15.230284651041298, -9.25226004093454], [15.321553379350966, -9.28358861602497], [15.41251819248144, -9.314613275414924], [15.503183566484982, -9.345338495171895], [15.593553868608977, -9.375768642557931], [15.683633360963128, -9.40590797969682], [15.773426204029215, -9.435760